# %% [markdown]
# # WAIC・WBIC
# ## WAIC・WBICについて
# ***
# - WAICは予測に扱うモデルを選択する指標
# - WBICは統計モデルと事前分布における最適な組み合わせを選択する指標
#
# ## 分析
# ***
# - 混合正規分布を真の分布としたときに下記モデリングでのWAIC・WBICを計算
#     - 正規分布
#     - 標準正規分布の混合分布

# %%
import warnings
warnings.filterwarnings('ignore')
import pymc3 as pm
from pymc3.distributions.dist_math import bound
import theano.tensor as tt
import theano
import numpy as np
np.random.seed(seed=32)

# %% [markdown]
# ## データセット作成

# %%
N = 100
a_true = 0.6
mean1 = 0
mean2 = 3
sd = 1
Y = np.random.randn(N)
Y[:int(N*a_true)] = Y[:int(N*a_true)] * sd + mean1
Y[int(N*a_true):] = Y[int(N*a_true):] * sd + mean2

# %% [markdown]
# ## 逆温度付きの正規分布

# %%
def normal_logp(value, mu, sd):
    tau = sd ** -2
    return (-tau * (value - mu)**2 + tt.log(tau / np.pi / 2.)) / 2

# %%
class NormalWithInverseTemperature(pm.Continuous):
    def __init__(self, beta=1, mu=0, sd=1, **kwargs):
        self.beta = beta
        self.sd = sd
        self.tau = sd**-2
        self.mu = mu
        super(NormalWithInverseTemperature, self).__init__(**kwargs)
    
    def logp(self, value):
        return bound(normal_logp(value, self.mu, self.sd), self.sd > 0) * self.beta

# %%
class MixtureNormalWithInverseTemperature(pm.Continuous):
    def __init__(self, a, mu, sd, beta=1, **kwargs):
        self.beta = beta
        self.sd = sd
        self.mu = mu
        self.a = a
        super(MixtureNormalWithInverseTemperature, self).__init__(**kwargs)

    def logp(self, value):
        sd = self.sd
        mu = self.mu
        a = self.a

        return pm.math.logsumexp(
            pm.math.stack([pm.math.log(1-a) + normal_logp(value, 0, sd),
                           pm.math.log(a) + normal_logp(value, mu, sd)])) * self.beta

# %% [markdown]
# ## 逆温度

# %%
beta = 1/np.log(N)

# %% [markdown]
# ## モデリング（正規分布）

# %%
with pm.Model() as model1:
    mu = pm.Normal("mu", mu=0, sd=1e4)
    sd = pm.HalfStudentT("sd", nu=3, sd=1e2)
    obs = dict()
    for i in range(N):
        obs[i] = NormalWithInverseTemperature(f"obs_{i}", mu=mu, sd=sd, observed=Y[i], beta=beta)

    y_pred = NormalWithInverseTemperature("pred", mu=mu, sd=sd, beta=beta, testval=0) # ppc
    log_likes = pm.Deterministic("log_likes", pm.math.stack([obs[i].logpt / beta for i in range(N)])) # to calc wbic
    
    trace1 = pm.sample(2000, tune=500, chains=4)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [pred, sd, mu]
# Sampling 4 chains: 100%|██████████| 10000/10000 [00:16<00:00, 610.80draws/s]

# %% [markdown]
# ## サンプリング結果

# %%
pm.summary(trace1)
# Out:
#                    mean        sd  mc_error   hpd_2.5  hpd_97.5        n_eff  \
# mu             1.267253  0.422240  0.004842  0.426495  2.098997  6515.455070
# pred           1.262877  4.205781  0.049410 -7.281878  9.285948  7619.647968
# sd             1.922319  0.331134  0.003968  1.343130  2.594741  6628.802147
# log_likes__83  1.000332
# log_likes__84  1.000227
# log_likes__85  1.000313
# log_likes__86  1.000032
# log_likes__87  0.999982
# log_likes__88  1.000206
# log_likes__89  1.000173
# log_likes__90  1.000346
# log_likes__91  1.000255
# log_likes__92  1.000346
# log_likes__93  1.000320
# log_likes__94  0.999972
# log_likes__95  1.000145
# log_likes__96  1.000282
# log_likes__97  1.000320
# log_likes__98  0.999972
# log_likes__99  1.000346
#
# [103 rows x 7 columns]

# %%
pm.traceplot(trace1)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12aee2b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a9f1860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12a821630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127d86a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x127885518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12725de80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12bd60668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12bf08b00>]],
#       dtype=object)

# %% [markdown]
# ## モデリング（混合正規分布）

# %%
with pm.Model() as model2:
    a = pm.Uniform('a', lower=0, upper=1)
    mu = pm.Normal('mu', mu=0, sd=1e4)
    obs = dict()
    for i in range(N):
        obs[i] = MixtureNormalWithInverseTemperature(f"obs_{i}", a=a, mu=mu, sd=1, observed=Y[i], beta=beta)
    
    y_pred = MixtureNormalWithInverseTemperature("pred", a=a, mu=mu, sd=1, testval=0, beta=beta)
    log_likes = pm.Deterministic("log_likes", pm.math.stack([obs[i].logpt / beta for i in range(N)]))
    
    trace2 = pm.sample(2000, tune=500, chains=4)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 2 jobs)
# NUTS: [pred, mu, a]
# Sampling 4 chains: 100%|██████████| 10000/10000 [01:07<00:00, 148.49draws/s]

# %% [markdown]
# ## サンプリング結果

# %%
pm.summary(trace2)
# Out:
#                    mean        sd  mc_error   hpd_2.5  hpd_97.5        n_eff  \
# mu             3.017173  0.455228  0.005637  2.142242  3.913845  6505.497447
# pred           1.386116  2.851473  0.036219 -3.798049  6.791605  6265.949341
# a              0.413650  0.117954  0.001542  0.199093  0.656165  7158.190644
# log_likes__0  -1.527419  0.208542  0.002673 -1.932117 -1.148780  7252.704115
# log_likes__1  -1.764098  0.156280  0.001774 -2.083849 -1.474395  8326.204693
# log_likes__2  -1.566930  0.169331  0.002137 -1.891587 -1.252808  8150.307192
# log_likes__3  -1.454618  0.196979  0.002531 -1.849679 -1.103009  7502.566562
# log_likes__4  -1.655708  0.158253  0.001926 -1.960792 -1.360665  8548.681073
# log_likes__5  -1.567345  0.169265  0.002136 -1.894064 -1.255468  8152.548420
# log_likes__6  -2.007611  0.244795  0.002877 -2.456087 -1.499973  6288.669033
# log_likes__7  -2.066252  0.305604  0.003864 -2.599320 -1.446649  5972.899532
# log_likes__8  -1.498713  0.206796  0.002652 -1.909240 -1.130602  7288.653626
# log_likes__9  -1.708345  0.213074  0.002725 -2.128428 -1.328734  7157.946995
# log_likes__10 -1.712721  0.213132  0.002726 -2.133286 -1.333256  7156.710095
# log_likes__11 -2.091891  0.384103  0.005280 -2.795638 -1.361078  5685.352046
# log_likes__12 -2.088382  0.349250  0.004626 -2.705136 -1.402029  5811.342840
# log_likes__13 -1.521882  0.177229  0.002260 -1.885288 -1.214308  7978.854997
# log_likes__14 -1.635248  0.211881  0.002712 -2.058674 -1.262242  7183.244060
# log_likes__93 -1.941096  0.321289  0.004662 -2.607598 -1.396524  5602.775164
# log_likes__94 -2.053757  0.289242  0.003590 -2.567181 -1.465456  6042.127257
# log_likes__95 -1.980815  0.405925  0.006141 -2.801198 -1.291335  5353.357261
# log_likes__96 -2.738490  0.553909  0.005690 -3.839222 -1.762913  8305.879069
# log_likes__97 -1.941004  0.321334  0.004663 -2.606413 -1.395199  5599.897410
# log_likes__98 -2.086117  0.342587  0.004507 -2.685971 -1.409448  5834.914763
# log_likes__99 -2.018211  0.322876  0.004131 -2.669242 -1.451039  7170.837193
#
#                    Rhat
# mu             1.000829
# pred           0.999894
# a              1.000505
# log_likes__0   1.000557
# log_likes__1   1.000552
# log_likes__2   1.000516
# log_likes__3   1.000549
# log_likes__4   1.000505
# log_likes__5   1.000516
# log_likes__6   1.000917
# log_likes__7   1.000987
# log_likes__8   1.000556
# log_likes__9   1.000559
# log_likes__10  1.000559
# log_likes__11  1.000974
# log_likes__12  1.000996
# log_likes__13  1.000527
# log_likes__14  1.000558
# log_likes__15  1.000547
# log_likes__16  1.000939
# log_likes__17  1.000535
# log_likes__18  1.000553
# log_likes__19  1.000526
# log_likes__20  1.000523
# log_likes__21  1.000560
# log_likes__22  1.000532
# log_likes__23  1.000557
# log_likes__24  1.000550
# log_likes__25  1.000558
# log_likes__26  1.000558
# ...                 ...
# log_likes__70  1.000928
# log_likes__71  1.000790
# log_likes__72  1.000986
# log_likes__73  1.000244
# log_likes__74  1.000684
# log_likes__75  1.000789
# log_likes__76  1.000570
# log_likes__77  1.000544
# log_likes__78  1.000626
# log_likes__79  1.000105
# log_likes__80  1.000634
# log_likes__81  1.000468
# log_likes__82  1.000101
# log_likes__83  1.000119
# log_likes__84  1.000638
# log_likes__85  1.000389
# log_likes__86  1.000869
# log_likes__87  1.000920
# log_likes__88  1.000509
# log_likes__89  1.000581
# log_likes__90  1.000105
# log_likes__91  1.000584
# log_likes__92  1.000094
# log_likes__93  1.000164
# log_likes__94  1.000975
# log_likes__95  1.000640
# log_likes__96  1.000513
# log_likes__97  1.000164
# log_likes__98  1.000997
# log_likes__99  1.000090
#
# [103 rows x 7 columns]

# %%
pm.traceplot(trace2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1359c9080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12e5de780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12ddc22e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1360dbdd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x137a555f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141a30f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x129ea3198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x136fb3390>]],
#       dtype=object)

# %% [markdown]
# ## WAICの計算

# %%
waic1 = pm.waic(trace1, model1)
waic2 = pm.waic(trace2, model2)
print('model1｜WAIC = {0}'.format(waic1.WAIC))
print('model2｜WAIC = {0}'.format(waic2.WAIC))
# Out:
# model1｜WAIC = 87.98024930487642
# model2｜WAIC = 84.97283886428576

# %% [markdown]
# ## WBICの計算

# %%
def wbic(log_likelihood):
    return - np.sum(log_likelihood, axis=1).mean()

print('model1｜WBIC = {0}'.format(wbic(trace1["log_likes"])))
print('model2｜WBIC = {0}'.format(wbic(trace2["log_likes"])))
# Out:
# model1｜WBIC = 201.86076321260654
# model2｜WBIC = 194.55660258745945
